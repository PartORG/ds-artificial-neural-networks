# %% [markdown]
# # Classification with Tensorflow/Keras
#
# In this notebook we will use a simple DNN for classification. We will use the vehicle emissions dataset provided by the city of Albuquerque [here](https://www.cabq.gov/abq-data/), in order to predict whether a vehicle will fail the emissions test with the goal to reduce pollution in Albuquerque. We borrow a lot from work done [here](https://github.com/Guli-Y/wimlds_emissions).
#
# Since it is a large dataset, we have taken a subset of the data. And we'll skip the exploration part.

# %%
# Import all the libraries I need
import numpy as np
import pandas as pd
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ignore Deprecation Warning
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.utils import plot_model

import keras 
from keras.models import Sequential # intitialize the ANN
from keras.layers import Dense, Activation, Dropout      # create layers

np.random.seed(42)
tf.random.set_seed(42)

df = pd.read_csv('../data/vehicle_emissions.csv', index_col=0)

# %% [markdown]
# **Variable Description:**
#
# |Variable|Definition   | Key  |  Type |
# |---|---|---|---|
# | RESULT | Passed the test? |   0 = Yes, 1 = No | Dichotomous |
# | VIN | Vehicle Identification Number | Text | 17 Char |
# | TEST_SDATE | Start of test date/time | MM/DD/YYYY HH:MM:SS | Date/Time |
# | MODEL_YEAR | Vehicle Model Year |	Number | Year |
# | GVWR | Gross Vehicle Weight | Number | Ratio |
# | ENGINE_SIZE | Engine Size volume | Number | Ratio |
# | ODOMETER | Odometer Reading, number of miles | Number | Ratio |
# | MAKE | Vehicle Make | Text | Nominal |

# %%
df.head()
# Out:
#             TEST_SDATE                VIN  MODEL_YEAR  GVWR  ENGINE_SIZE
# 0  2014-01-06 09:17:00  JTEHP21A470207451        2007  5360         3300  \
# 1  2014-12-05 12:29:00  JT3HN86R1Y0264434        2000  5250         3400
# 2  2014-12-02 11:45:00  2GTEC19TX31323349        2003  6100         5300
# 3  2014-09-19 08:41:00  2C3LA53G68H231030        2008  3875         3500
# 4  2014-10-20 13:28:00  1GCCS19X638205261        2003  3625         4300
#
#    ODOMETER  RESULT       MAKE
# 0     58795       0     TOYOTA
# 1    236529       0     TOYOTA
# 2    173509       0        GMC
# 3     57883       0   CHRYSLER
# 4    198516       0  CHEVROLET

# %% [markdown]
# ## Data Cleaning
#
# Looking at the information about each column and the missing values shows us that we have to clean our data before we can use it for modelling.

# %%
# transform TEST_SDATE to datetime object
df['TEST_SDATE'] = pd.to_datetime(df['TEST_SDATE'])

# %% [markdown]
# We approximate vehicle age in years by subtracting the model year from the test year and adding 2 years to avoid zero-age vehicles (e.g., cars tested in their model year) before dividing mileage by age.

# %%
# engineering VEHICLE_AGE
df['VEHICLE_AGE'] = df.TEST_SDATE.dt.year.astype('int') - df.MODEL_YEAR.astype('int') + 2

# %% [markdown]
# We clean the VIN column and fill missing or zero GVWR values, if possible otherwise drop them.

# %%
print(colored(f'\nRecords in input data: {df.shape[0]}', 'red'))
# get median GVWR for each VIN
# clean VIN
df['VIN'] = df['VIN'].astype('string').str.strip().str.lower()
# get median GVWR
tmp = df[['VIN', 'GVWR']].groupby('VIN').agg({'GVWR':'median'})
tmp.reset_index(inplace=True)
# merge tmp with df
df = df.merge(tmp, how='left', on='VIN', suffixes=('_0',''))
# replace 0 with np.nan
df.loc[df.GVWR==0, 'GVWR'] = np.nan
df.loc[df.GVWR_0==0, 'GVWR_0'] = np.nan
# using GVWR_0 fill missing values in GVWR
df['GVWR'] = df.GVWR.fillna(df.GVWR_0)
# keep GVW and drop GVWR_0
df = df.drop(columns=['GVWR_0'])
# drop na in GVWR
print('\nRecords with missing GVWR:', df.GVWR.isnull().sum())
df = df[~df.GVWR.isnull()]
# drop low numbers in GVWR
df = df[df.GVWR > 1000]
print(colored(f'\nRecords after droping rows where GVWR is < 1000 or missing: {df.shape[0]}', 'red'))
# Out:
# Records in input data: 164108
#
# Records with missing GVWR: 6102
#
# Records after droping rows where GVWR is < 1000 or missing: 157998

# %% [markdown]
# In order to have independent test results, only keep the first if there are multiple in 90 days.

# %%
# if a vehicle has multiple test records within 90 days, keep earliest record 
df = df.sort_values('TEST_SDATE')
df = df.loc[~(df.groupby('VIN')['TEST_SDATE'].diff() < np.timedelta64(90, 'D'))]
print(colored(f'\nRecords after keeping only the earliest test within 90 days for each vehicle: {df.shape[0]}', 'red'))
# Out:
# Records after keeping only the earliest test within 90 days for each vehicle: 146078

# %% [markdown]
# Now we can drop the `VIN` column as it does not contain useful information.

# %%
df = df.drop(columns=['VIN'])

# %% [markdown]
# Clean the `ODOMETER` column by removing zeros and `8888888` values.

# %%
# drop 0s in ODOMETER and remove 8888888
print('\nRecords where ODOMETER = 0:', df[df.ODOMETER==0].shape[0])
df = df[(df.ODOMETER!=0) & (df.ODOMETER!=8888888)]
print(colored(f'\nRecords after dropping rows where ODOMETER is 0 or 8,888,888: {df.shape[0]}', 'red'))
# Out:
# Records where ODOMETER = 0: 821
#
# Records after dropping rows where ODOMETER is 0 or 8,888,888: 145195

# %% [markdown]
# We calculate the miles per year.

# %%
# engineer MILE_YEAR from ODOMETER
df['MILE_YEAR'] = np.round(df['ODOMETER']/df['VEHICLE_AGE'], 2)

# %% [markdown]
# Based on the engineered features `MILE_YEAR` and `VEHICLE_AGE` we remove clear outliers: records with over 40,000 miles per year and vehicles older than 10 years showing under 1,000 miles per year.

# %%
# remove the outliers
df = df[df.MILE_YEAR <= 40000]
df = df[~((df.VEHICLE_AGE > 10) & (df.MILE_YEAR < 1000))]
print(colored(f'\nRecords after dropping rows where MILE_YEAR > 40,000 or (VEHICLE_AGE > 10 and MILE_YEAR < 1,000): {df.shape[0]}', 'red'))
# Out:
# Records after dropping rows where MILE_YEAR > 40,000 or (VEHICLE_AGE > 10 and MILE_YEAR < 1,000): 144368

# %% [markdown]
# We calculate the engine - weight ratio.

# %%
# engineer ENGINE_WEIGHT_RATIO
df['ENGINE_WEIGHT_RATIO'] = np.round(df['ENGINE_SIZE']/df['GVWR'], 2)

# %% [markdown]
# We drop remaining nan's.

# %%
df = df.dropna()
df = df.reset_index(drop=True)

# %% [markdown]
# And select a subset of columns, which are most useful.

# %%
cols = ['MODEL_YEAR',
        'VEHICLE_AGE',
        'MILE_YEAR',
        'MAKE',
        'ENGINE_WEIGHT_RATIO',
        'RESULT'
        ]
df = df[cols]

# %% [markdown]
# To avoid an explosion of columns after one-hot encoding, we relabel any make appearing in less than 1% of cars as `other`.

# %%
make_threshold = 0.01
# create a make label 'other' for all makes that account for <1% of cars
value_counts_norm = df['MAKE'].value_counts(normalize = True)
to_other = value_counts_norm[value_counts_norm < make_threshold]
#print(f"\n{len(to_other)} make labels each account for less than {round((make_threshold *100), 2)}% of cars and together account for {(round(to_other.sum(), 4)) *100}% of cars")
to_keep = value_counts_norm[value_counts_norm >= make_threshold]
makes_keep = list(to_keep.index)
makes_keep.sort()
other_makes = [make for make in df['MAKE'].unique() if make not in makes_keep]
df['MAKE'] = df['MAKE'].replace(other_makes, 'other')
# one-hot encode the make column
df = pd.get_dummies(df, drop_first=True, dtype=float)

# %% [markdown]
# We split our data into train-, validation- and test-sets.

# %%
# Use a utility from sklearn to split and shuffle your dataset.
train_df, test_df = train_test_split(df, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.2)

# Form np arrays of labels and features.
train_labels = np.array(train_df.pop('RESULT'))
val_labels = np.array(val_df.pop('RESULT'))
test_labels = np.array(test_df.pop('RESULT'))

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)

print(f'Average class probability in training set:   {train_labels.mean():.4f}')
print(f'Average class probability in validation set: {val_labels.mean():.4f}')
print(f'Average class probability in test set:       {test_labels.mean():.4f}')
# Out:
# Average class probability in training set:   0.0699
# Average class probability in validation set: 0.0690
# Average class probability in test set:       0.0683

# %% [markdown]
# We see that we are dealing with a highly imbalanced data set. We will use class weights to deal with that.

# %% [markdown]
# Neural networks are highly sensitive to the scale of the input data, and small differences in scale can have a significant impact on the performance of the network. By properly scaling input data, we can ensure that the neural network is able to effectively learn and make accurate predictions. Therefore we add a normalizer layer which we adapt on the train set only, to avoid data leakage.

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(train_features)

# %% [markdown]
# Up to this point the steps should look familiar to you. But now we will create our very simple Dense Neural Network with:
# - a normalizer layer
# - a dense layer with 4 nodes and gelu activation
# - a hidden layers with 4 nodes and gelu activation
# - a dropout layer (The Dropout layer randomly sets input units to 0 with a frequency of rate at each step during training time, which helps prevent overfitting. Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over all inputs is unchanged.)
# - an output layer which is used to predict a car's test result. The output layer has a sigmoid activation function, which is used to 'squash' all our outputs to be between 0 and 1.
#
# We then compile our NN with different hyperparameters like:
#
# 1. Optimizers:
# While the architecture of the Neural Network plays an important role when extracting information from data, all (most) are being optimized through update rules based on the gradient of the loss function.
# The update rules are determined by the Optimizer. The performance and update speed may heavily vary from optimizer to optimizer. The gradient tells us the update direction, but it is still unclear how big of a step we might take. Short steps keep us on track, but it might take a very long time until we reach a (local) minimum. Large steps speed up the process, but it might push us off the right direction.
# Adam and RMSProp are two very popular optimizers still being used in most neural networks. Both update the variables using an exponential decaying average of the gradient and its squared. But there are more, have a [look](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers).
#
# 2. Loss
# Different [loss functions](https://www.tensorflow.org/api_docs/python/tf/keras/losses)
#
# 3. Metrics
#
# 4. and so on. There are many. Have a look yourself in the [documentary](https://www.tensorflow.org/api_docs/python/tf/keras)

# %%
model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
opt = tf.keras.optimizers.AdamW(learning_rate=3e-4, weight_decay=1e-4)
model.compile(optimizer=opt,
            loss=tf.keras.losses.BinaryCrossentropy(),
            metrics=[tf.keras.metrics.Precision(thresholds=0.5), tf.keras.metrics.Recall(thresholds=0.5)])

# Build the model so plot_model has concrete input shapes
model.build((None, train_features.shape[1]))

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, 
    show_layer_names=True, dpi=96
)

# %% [markdown]
# The goal is to predict failed test results, but we don't have very many of those positive samples to work with, so we would want to have the classifier heavily weight the few examples that are available. We can do this by passing Keras weights for each class through a parameter. These will cause the model to "pay more attention" to examples from an under-represented class. Note, however, that this does not increase in any way the amount of information of your dataset. Let's see how it works out.

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
total = len(train_labels)
print(f"Total: {total}")
pos = sum(train_labels)
print(f"POS: {pos}")
neg = total - pos
print(f"NEG: {neg}")

weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Total: 92395
# POS: 6458
# NEG: 85937
# Weight for class 0: 0.54
# Weight for class 1: 7.15

# %%
training = model.fit(
    train_features,
    train_labels,
    batch_size=64,
    epochs=15,
    validation_data=(val_features, val_labels), 
    verbose=1,
    class_weight=class_weight)
# Out:
# Epoch 1/15
# 1444/1444 [==============================] - 4s 2ms/step - loss: 0.6822 - precision_2: 0.0839 - recall_2: 0.6753 - val_loss: 0.6822 - val_precision_2: 0.1089 - val_recall_2: 0.6968
# Epoch 2/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6417 - precision_2: 0.1149 - recall_2: 0.6819 - val_loss: 0.6484 - val_precision_2: 0.1220 - val_recall_2: 0.6711
# Epoch 3/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6305 - precision_2: 0.1245 - recall_2: 0.6710 - val_loss: 0.6409 - val_precision_2: 0.1268 - val_recall_2: 0.6880
# Epoch 4/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6249 - precision_2: 0.1273 - recall_2: 0.6751 - val_loss: 0.6188 - val_precision_2: 0.1286 - val_recall_2: 0.6780
# Epoch 5/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6235 - precision_2: 0.1284 - recall_2: 0.6742 - val_loss: 0.6334 - val_precision_2: 0.1264 - val_recall_2: 0.6993
# Epoch 6/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6213 - precision_2: 0.1284 - recall_2: 0.6871 - val_loss: 0.6151 - val_precision_2: 0.1276 - val_recall_2: 0.6930
# Epoch 7/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6190 - precision_2: 0.1283 - recall_2: 0.6908 - val_loss: 0.6151 - val_precision_2: 0.1276 - val_recall_2: 0.6999
# Epoch 8/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6178 - precision_2: 0.1288 - recall_2: 0.6892 - val_loss: 0.6206 - val_precision_2: 0.1270 - val_recall_2: 0.7100
# Epoch 9/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6162 - precision_2: 0.1280 - recall_2: 0.6929 - val_loss: 0.6192 - val_precision_2: 0.1279 - val_recall_2: 0.7087
# Epoch 10/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6167 - precision_2: 0.1292 - recall_2: 0.6963 - val_loss: 0.6151 - val_precision_2: 0.1277 - val_recall_2: 0.7119
# Epoch 11/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6157 - precision_2: 0.1287 - recall_2: 0.7011 - val_loss: 0.6208 - val_precision_2: 0.1267 - val_recall_2: 0.7207
# Epoch 12/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6145 - precision_2: 0.1282 - recall_2: 0.7019 - val_loss: 0.6103 - val_precision_2: 0.1283 - val_recall_2: 0.7112
# Epoch 13/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6142 - precision_2: 0.1282 - recall_2: 0.7067 - val_loss: 0.5943 - val_precision_2: 0.1301 - val_recall_2: 0.6937
# Epoch 14/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6146 - precision_2: 0.1296 - recall_2: 0.7011 - val_loss: 0.6065 - val_precision_2: 0.1288 - val_recall_2: 0.7062
# Epoch 15/15
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6143 - precision_2: 0.1291 - recall_2: 0.7050 - val_loss: 0.6064 - val_precision_2: 0.1286 - val_recall_2: 0.7100

# %% [markdown]
# Let's have a look at our recall at each epoch on the train- and validation set

# %%
# summarize history for recall
plt.plot(training.history['recall_2'])
plt.plot(training.history['val_recall_2'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Exercise:**
# Plot the loss against the epochs, and discuss the result!

# %%
# summarize history for loss
plt.plot(training.history['loss'])
plt.plot(training.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(test_features)

# Plotting the confusing matrix
mat = confusion_matrix(test_labels, y_pred.round())
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')
# Out:
# 903/903 [==============================] - 1s 1ms/step
# Text(113.9222222222222, 0.5, 'predicted label')

# %%
recall = recall_score(test_labels, y_pred.round())
round(recall, 2)
# Out:
# 0.72

# %% [markdown]
# The recall tells us what fraction of the vehicles that will fail the emissions test, we actually catch. To reduce pollution in Albuquerque we want this to be as high as possible without having to test as few as possible vehicles who will pass the test. So that we save money.

# %% [markdown]
# **Exercise:**
# - What happens when you add layers to our model?
# - What happens when you change the number of nodes?
# - What when you change the batch size or the optimizer?

# %%
# 2 - More layers

model_2 = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dense(8, activation='gelu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
opt = tf.keras.optimizers.AdamW(learning_rate=3e-4, weight_decay=1e-4)
model_2.compile(optimizer=opt,
            loss=tf.keras.losses.BinaryCrossentropy(),
            metrics=[tf.keras.metrics.Precision(thresholds=0.5), tf.keras.metrics.Recall(thresholds=0.5)])

# Build the model so plot_model has concrete input shapes
model_2.build((None, train_features.shape[1]))

plot_model(
    model_2, to_file='model_2.png', show_shapes=True, 
    show_layer_names=True, dpi=96
)


# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
total = len(train_labels)
print(f"Total: {total}")
pos = sum(train_labels)
print(f"POS: {pos}")
neg = total - pos
print(f"NEG: {neg}")

weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

training = model_2.fit(
    train_features,
    train_labels,
    batch_size=64,
    epochs=50,
    validation_data=(val_features, val_labels), 
    verbose=1,
    class_weight=class_weight)
# Out:
# Total: 92395
# POS: 6458
# NEG: 85937
# Weight for class 0: 0.54
# Weight for class 1: 7.15
# Epoch 1/50
# 1444/1444 [==============================] - 4s 2ms/step - loss: 0.6552 - precision_4: 0.1037 - recall_4: 0.6909 - val_loss: 0.6226 - val_precision_4: 0.1231 - val_recall_4: 0.6761
# Epoch 2/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6239 - precision_4: 0.1252 - recall_4: 0.6902 - val_loss: 0.6110 - val_precision_4: 0.1272 - val_recall_4: 0.6999
# Epoch 3/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6178 - precision_4: 0.1267 - recall_4: 0.6996 - val_loss: 0.6214 - val_precision_4: 0.1258 - val_recall_4: 0.7062
# Epoch 4/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6166 - precision_4: 0.1289 - recall_4: 0.7019 - val_loss: 0.6097 - val_precision_4: 0.1268 - val_recall_4: 0.6968
# Epoch 5/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6155 - precision_4: 0.1290 - recall_4: 0.7005 - val_loss: 0.6305 - val_precision_4: 0.1255 - val_recall_4: 0.7276
# Epoch 6/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6159 - precision_4: 0.1280 - recall_4: 0.7061 - val_loss: 0.6018 - val_precision_4: 0.1285 - val_recall_4: 0.7006
# Epoch 7/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6133 - precision_4: 0.1285 - recall_4: 0.7066 - val_loss: 0.6022 - val_precision_4: 0.1288 - val_recall_4: 0.6949
# Epoch 8/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6130 - precision_4: 0.1289 - recall_4: 0.7044 - val_loss: 0.6168 - val_precision_4: 0.1262 - val_recall_4: 0.7181
# Epoch 9/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6113 - precision_4: 0.1286 - recall_4: 0.7080 - val_loss: 0.6151 - val_precision_4: 0.1275 - val_recall_4: 0.7075
# Epoch 10/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6126 - precision_4: 0.1287 - recall_4: 0.7075 - val_loss: 0.6198 - val_precision_4: 0.1261 - val_recall_4: 0.7169
# Epoch 11/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6121 - precision_4: 0.1288 - recall_4: 0.7106 - val_loss: 0.6185 - val_precision_4: 0.1264 - val_recall_4: 0.7169
# Epoch 12/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6118 - precision_4: 0.1283 - recall_4: 0.7094 - val_loss: 0.6030 - val_precision_4: 0.1285 - val_recall_4: 0.7075
# Epoch 13/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6106 - precision_4: 0.1284 - recall_4: 0.7114 - val_loss: 0.5807 - val_precision_4: 0.1312 - val_recall_4: 0.6773
# Epoch 14/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6114 - precision_4: 0.1289 - recall_4: 0.7086 - val_loss: 0.5994 - val_precision_4: 0.1293 - val_recall_4: 0.6981
# Epoch 15/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6114 - precision_4: 0.1296 - recall_4: 0.7107 - val_loss: 0.6003 - val_precision_4: 0.1287 - val_recall_4: 0.7087
# Epoch 16/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6106 - precision_4: 0.1289 - recall_4: 0.7086 - val_loss: 0.6051 - val_precision_4: 0.1287 - val_recall_4: 0.7100
# Epoch 17/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6111 - precision_4: 0.1286 - recall_4: 0.7098 - val_loss: 0.6054 - val_precision_4: 0.1292 - val_recall_4: 0.7131
# Epoch 18/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6098 - precision_4: 0.1296 - recall_4: 0.7112 - val_loss: 0.6137 - val_precision_4: 0.1285 - val_recall_4: 0.7175
# Epoch 19/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6108 - precision_4: 0.1289 - recall_4: 0.7140 - val_loss: 0.6155 - val_precision_4: 0.1274 - val_recall_4: 0.7163
# Epoch 20/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6099 - precision_4: 0.1292 - recall_4: 0.7112 - val_loss: 0.6195 - val_precision_4: 0.1274 - val_recall_4: 0.7219
# Epoch 21/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6094 - precision_4: 0.1292 - recall_4: 0.7128 - val_loss: 0.5963 - val_precision_4: 0.1293 - val_recall_4: 0.6999
# Epoch 22/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6093 - precision_4: 0.1296 - recall_4: 0.7134 - val_loss: 0.6185 - val_precision_4: 0.1262 - val_recall_4: 0.7250
# Epoch 23/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6087 - precision_4: 0.1289 - recall_4: 0.7166 - val_loss: 0.6062 - val_precision_4: 0.1290 - val_recall_4: 0.7081
# Epoch 24/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6091 - precision_4: 0.1294 - recall_4: 0.7109 - val_loss: 0.6140 - val_precision_4: 0.1272 - val_recall_4: 0.7219
# Epoch 25/50
# 1444/1444 [==============================] - 4s 3ms/step - loss: 0.6087 - precision_4: 0.1286 - recall_4: 0.7196 - val_loss: 0.6292 - val_precision_4: 0.1263 - val_recall_4: 0.7351
# Epoch 26/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6084 - precision_4: 0.1291 - recall_4: 0.7177 - val_loss: 0.6162 - val_precision_4: 0.1273 - val_recall_4: 0.7169
# Epoch 27/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6085 - precision_4: 0.1292 - recall_4: 0.7148 - val_loss: 0.6001 - val_precision_4: 0.1291 - val_recall_4: 0.7056
# Epoch 28/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6087 - precision_4: 0.1295 - recall_4: 0.7142 - val_loss: 0.6027 - val_precision_4: 0.1280 - val_recall_4: 0.7119
# Epoch 29/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6089 - precision_4: 0.1287 - recall_4: 0.7165 - val_loss: 0.6173 - val_precision_4: 0.1287 - val_recall_4: 0.7188
# Epoch 30/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6087 - precision_4: 0.1291 - recall_4: 0.7163 - val_loss: 0.5964 - val_precision_4: 0.1295 - val_recall_4: 0.6987
# Epoch 31/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6079 - precision_4: 0.1304 - recall_4: 0.7149 - val_loss: 0.6298 - val_precision_4: 0.1260 - val_recall_4: 0.7332
# Epoch 32/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6079 - precision_4: 0.1298 - recall_4: 0.7138 - val_loss: 0.6305 - val_precision_4: 0.1240 - val_recall_4: 0.7313
# Epoch 33/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6074 - precision_4: 0.1287 - recall_4: 0.7188 - val_loss: 0.6154 - val_precision_4: 0.1269 - val_recall_4: 0.7207
# Epoch 34/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6080 - precision_4: 0.1295 - recall_4: 0.7124 - val_loss: 0.5982 - val_precision_4: 0.1289 - val_recall_4: 0.7043
# Epoch 35/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6070 - precision_4: 0.1300 - recall_4: 0.7163 - val_loss: 0.6051 - val_precision_4: 0.1282 - val_recall_4: 0.7087
# Epoch 36/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6079 - precision_4: 0.1296 - recall_4: 0.7172 - val_loss: 0.6117 - val_precision_4: 0.1269 - val_recall_4: 0.7156
# Epoch 37/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6079 - precision_4: 0.1298 - recall_4: 0.7193 - val_loss: 0.6287 - val_precision_4: 0.1262 - val_recall_4: 0.7269
# Epoch 38/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6075 - precision_4: 0.1302 - recall_4: 0.7188 - val_loss: 0.6234 - val_precision_4: 0.1261 - val_recall_4: 0.7276
# Epoch 39/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6077 - precision_4: 0.1295 - recall_4: 0.7162 - val_loss: 0.6072 - val_precision_4: 0.1268 - val_recall_4: 0.7112
# Epoch 40/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6071 - precision_4: 0.1293 - recall_4: 0.7165 - val_loss: 0.5939 - val_precision_4: 0.1289 - val_recall_4: 0.7062
# Epoch 41/50
# 1444/1444 [==============================] - 4s 2ms/step - loss: 0.6067 - precision_4: 0.1297 - recall_4: 0.7132 - val_loss: 0.5992 - val_precision_4: 0.1290 - val_recall_4: 0.7068
# Epoch 42/50
# 1444/1444 [==============================] - 4s 3ms/step - loss: 0.6079 - precision_4: 0.1301 - recall_4: 0.7171 - val_loss: 0.6141 - val_precision_4: 0.1276 - val_recall_4: 0.7137
# Epoch 43/50
# 1444/1444 [==============================] - 4s 3ms/step - loss: 0.6068 - precision_4: 0.1305 - recall_4: 0.7146 - val_loss: 0.6132 - val_precision_4: 0.1268 - val_recall_4: 0.7175
# Epoch 44/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6065 - precision_4: 0.1293 - recall_4: 0.7207 - val_loss: 0.6054 - val_precision_4: 0.1271 - val_recall_4: 0.7119
# Epoch 45/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6070 - precision_4: 0.1304 - recall_4: 0.7169 - val_loss: 0.6128 - val_precision_4: 0.1265 - val_recall_4: 0.7106
# Epoch 46/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6057 - precision_4: 0.1300 - recall_4: 0.7200 - val_loss: 0.6085 - val_precision_4: 0.1280 - val_recall_4: 0.7200
# Epoch 47/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6069 - precision_4: 0.1307 - recall_4: 0.7169 - val_loss: 0.6064 - val_precision_4: 0.1274 - val_recall_4: 0.7125
# Epoch 48/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6061 - precision_4: 0.1306 - recall_4: 0.7166 - val_loss: 0.6211 - val_precision_4: 0.1256 - val_recall_4: 0.7244
# Epoch 49/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6061 - precision_4: 0.1302 - recall_4: 0.7168 - val_loss: 0.5938 - val_precision_4: 0.1285 - val_recall_4: 0.7024
# Epoch 50/50
# 1444/1444 [==============================] - 3s 2ms/step - loss: 0.6068 - precision_4: 0.1304 - recall_4: 0.7231 - val_loss: 0.6170 - val_precision_4: 0.1263 - val_recall_4: 0.7213

# %%
# summarize history for recall
plt.plot(training.history['recall_4'])
plt.plot(training.history['val_recall_4'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(training.history['loss'])
plt.plot(training.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

y_pred_2 = model_2.predict(test_features)

# Plotting the confusing matrix
mat = confusion_matrix(test_labels, y_pred_2.round())
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label')

recall_2 = recall_score(test_labels, y_pred_2.round())
round(recall_2, 2)
# Out:
# 903/903 [==============================] - 1s 1ms/step
# 0.74
